# %% [markdown]
# ![Banner](https://hmdvideos.sfo3.cdn.digitaloceanspaces.com/Programas%20de%20Entrenamiento/Python/banner.png)
#
# # Bienvenido al Curso: Python de Cero a Pro con Google Colab
#
# **Autor:** `Héctor Martínez`
# <!-- **Agencia / Institución:** [Nombre de tu Agencia o Empresa]   -->
# **Versión del curso:** 1.0 – Marzo 2026
# <!-- **Contacto:** [tu email o LinkedIn / página web]   -->
#
# <br>
#
# ¡Gracias por elegir este curso! Está diseñado para llevarte desde cero conocimientos de programación hasta un nivel intermedio sólido, con proyectos reales y enfoque 100% práctico usando **Google Colab** (sin instalaciones locales).
#
# ### ¿Para quién es este curso?
# - Personas sin experiencia previa en programación
# - Profesionales que quieren cambiar o complementar su carrera
# - Estudiantes y autodidactas
# - Empresas e instituciones que buscan capacitar personal
#
# ### Objetivos generales al finalizar el curso
# Al terminar los 8 módulos podrás:
# - Escribir scripts limpios y estructurados en Python 3.12+
# - Resolver problemas reales usando estructuras de datos, funciones y OOP
# - Manejar archivos, excepciones y errores de forma profesional
# - Trabajar con bibliotecas esenciales (random, requests, pandas intro)
# - Construir pequeños proyectos integradores y tener un portafolio inicial
# - Entender buenas prácticas (PEP 8, Git básico, testing simple)
# - Estar preparado para especializarte en: Data Science, Desarrollo Web, Automatización o IA
#
# ### Estructura modular del curso
#
# | Módulo | Título                              | Duración aprox. | Contenido principal                              | Objetivos clave al terminar el módulo                                                                 |
# |--------|-------------------------------------|------------------|--------------------------------------------------|-------------------------------------------------------------------------------------------------------|
# | 00     | Bienvenida (este cuaderno)          | 15–30 min       | Introducción, objetivos, mapa del curso          | Conocer el alcance, expectativas y cómo navegar el curso                                             |
# | 1      | Fundamentos Básicos                 | 5 horas         | Variables, tipos, operadores, strings, input     | Manejar sintaxis básica y resolver problemas elementales                                              |
# | 2      | Control de Flujo y Lógica           | 6 horas         | if/elif/else, for/while, range, break/continue   | Tomar decisiones y repetir acciones de forma controlada                                              |
# | 3      | Estructuras de Datos Básicas        | 6 horas         | Listas, tuplas, sets, diccionarios, comprehensions | Organizar y manipular colecciones de datos eficientemente                                            |
# | 4      | Funciones y Modularidad             | 5 horas         | Parámetros, return, scope, *args/**kwargs, lambda | Escribir código reutilizable y organizado                                                            |
# | 5      | Manejo de Archivos y Excepciones    | 5 horas         | open/with, CSV/JSON, try/except/raise            | Interactuar con archivos y hacer programas robustos frente a errores                                 |
# | 6      | Programación Orientada a Objetos    | 6 horas         | Clases, objetos, herencia, polimorfismo, encapsulación | Modelar problemas del mundo real con OOP                                                              |
# | 7      | Bibliotecas Esenciales y Buenas Prácticas | 6 horas   | random/math/datetime, requests, pandas intro, Git básico, PEP 8 | Usar el ecosistema Python y escribir código profesional                                              |
# | 8      | Proyectos Integradores y Avanzados  | 7 horas         | Decoradores, async intro, unittest, capstone     | Integrar todo en proyectos reales y prepararte para especializaciones                                 |
#
# ### ¿Qué espero de ti como alumno?
# - Dedicar entre 4–10 horas por semana (ritmo flexible)
# - Ejecutar TODAS las celdas de demostración
# - Completar los retos progresivos (¡son la clave para aprender!)
# - Hacer el proyecto de cada módulo y el capstone final
# - Compartir dudas en los comentarios o foro (si lo habilitas en Udemy)
#
# ### ¿Cómo navegar el curso?
# Haz clic en los enlaces de cada módulo (recomendado: haz "Copy to Drive" en cada uno para tener tu propia copia editable):
#
# - [Módulo 1 – Fundamentos Básicos](https://colab.research.google.com/drive/1ePVNAcQ5sUFAzDNkSwbyLYVbVMit7ggB?usp=sharing#copy=true)
# - [Módulo 2 – Control de Flujo y Lógica](https://colab.research.google.com/drive/1qgp10CWUr48HW13yL3xuUiCksQF51FBq?usp=sharing#copy=true)
# - [Módulo 3 – Estructuras de Datos Básicas](https://colab.research.google.com/drive/1fIpcJqhY9vWKoGYzD8zs27jZcQirwHV-?usp=sharing#copy=true)
# - [Módulo 4 – Funciones y Modularidad](https://colab.research.google.com/drive/1_GydC6_BKE8UvgamhBtVfXT8jDXqtIXF?usp=sharing#copy=true)
# - [Módulo 5 – Manejo de Archivos y Excepciones](https://colab.research.google.com/drive/1Ugx4Oy-QH8N4RcYkw6ou3H1p3l1oUXHa?usp=sharing#copy=true)
# - [Módulo 6 – Programación Orientada a Objetos](https://colab.research.google.com/drive/1k_crz4e_XDpgksTeqLK02QPH5RF3Uq3E?usp=sharing#copy=true)
# - [Módulo 7 – Bibliotecas y Mejores Prácticas](https://colab.research.google.com/drive/1eV9HBOPqfEo4MNhjvGiC7-W1CQuKtf9h?usp=sharing#copy=true)
# - [Módulo 8 – Proyectos Integradores y Avanzados](https://colab.research.google.com/drive/1h9GjkisvBdpLwcqAw9UcaheQSvrW2-p9?usp=sharing#copy=true)
#
# **Recomendación:** Abre cada módulo, haz clic en **Archivo → Guardar una copia en Drive** y trabaja siempre en tu copia personal.
#
# ¡Empecemos!
# Ejecuta la celda siguiente para verificar que todo funciona:

# %%
print("¡Bienvenido al curso!")
print("Versión de Python en Colab:")
import sys
print(sys.version)
